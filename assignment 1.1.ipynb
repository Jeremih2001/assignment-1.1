# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
x=np.linspace(-10,10,20)
sine=np.sin(x) ## universal function :: ufunc

# %%
x
# Out:
# array([-10.        ,  -8.94736842,  -7.89473684,  -6.84210526,
#         -5.78947368,  -4.73684211,  -3.68421053,  -2.63157895,
#         -1.57894737,  -0.52631579,   0.52631579,   1.57894737,
#          2.63157895,   3.68421053,   4.73684211,   5.78947368,
#          6.84210526,   7.89473684,   8.94736842,  10.        ])

# %%
sine
# Out:
# array([ 0.54402111, -0.4594799 , -0.99916962, -0.53027082,  0.47389753,
#         0.99970104,  0.5163796 , -0.48818921, -0.99996678, -0.50235115,
#         0.50235115,  0.99996678,  0.48818921, -0.5163796 , -0.99970104,
#        -0.47389753,  0.53027082,  0.99916962,  0.4594799 , -0.54402111])

# %%
plt.plot(x,sine)

# %%
x=np.linspace(-10,10,1000)
sine=np.sin(x) 
plt.plot(x,sine)
plt.grid(20)

# %% [markdown]
# ## y=tan(x)

# %%
x=np.linspace(-10,10,30)
tangent=np.tan(x) ## universal function :: ufunc

# %%
x
# Out:
# array([-10.        ,  -9.31034483,  -8.62068966,  -7.93103448,
#         -7.24137931,  -6.55172414,  -5.86206897,  -5.17241379,
#         -4.48275862,  -3.79310345,  -3.10344828,  -2.4137931 ,
#         -1.72413793,  -1.03448276,  -0.34482759,   0.34482759,
#          1.03448276,   1.72413793,   2.4137931 ,   3.10344828,
#          3.79310345,   4.48275862,   5.17241379,   5.86206897,
#          6.55172414,   7.24137931,   7.93103448,   8.62068966,
#          9.31034483,  10.        ])

# %%
tangent
# Out:
# array([ -0.64836083,   0.11493526,   1.03809675,  12.95241104,
#         -1.42288101,  -0.27518568,   0.44791219,   2.01824627,
#         -4.27801098,  -0.76259104,   0.03816289,   0.89096257,
#          6.47019319,  -1.68228493,  -0.35917787,   0.35917787,
#          1.68228493,  -6.47019319,  -0.89096257,  -0.03816289,
#          0.76259104,   4.27801098,  -2.01824627,  -0.44791219,
#          0.27518568,   1.42288101, -12.95241104,  -1.03809675,
#         -0.11493526,   0.64836083])

# %%
plt.plot(x,tangent)
plt.grid(50)

# %%
x=np.linspace(-10,10,1000)
tangent=np.tan(x) 
plt.plot(x,tangent)
plt.grid(20)

# %% [markdown]
# ## y=cos(m)

# %%
m=np.linspace(-10,10,30)
cosine=np.cos(m) ## universal function :: ufunc

# %%
m
# Out:
# array([-10.        ,  -9.31034483,  -8.62068966,  -7.93103448,
#         -7.24137931,  -6.55172414,  -5.86206897,  -5.17241379,
#         -4.48275862,  -3.79310345,  -3.10344828,  -2.4137931 ,
#         -1.72413793,  -1.03448276,  -0.34482759,   0.34482759,
#          1.03448276,   1.72413793,   2.4137931 ,   3.10344828,
#          3.79310345,   4.48275862,   5.17241379,   5.86206897,
#          6.55172414,   7.24137931,   7.93103448,   8.62068966,
#          9.31034483,  10.        ])

# %%
cosine
# Out:
# array([-0.83907153, -0.99345967, -0.69376812, -0.07697663,  0.57499851,
#         0.96415961,  0.91263317,  0.44397034, -0.2276176 , -0.79516858,
#        -0.99927259, -0.74664001, -0.15274137,  0.51097062,  0.94113375,
#         0.94113375,  0.51097062, -0.15274137, -0.74664001, -0.99927259,
#        -0.79516858, -0.2276176 ,  0.44397034,  0.91263317,  0.96415961,
#         0.57499851, -0.07697663, -0.69376812, -0.99345967, -0.83907153])

# %%
plt.plot(m,cosine)

# %%
m=np.linspace(-10,10,1000)
cosine=np.cos(m) 
plt.plot(m,cosine)
plt.grid(20)
